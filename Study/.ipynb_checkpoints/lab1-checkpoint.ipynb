# %%
# linear algebra
import numpy as np

# data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd

# for plotting graphs
import matplotlib.pyplot as plt
import seaborn as sns

# library for getting mutual info
from sklearn.feature_selection import mutual_info_regression

# for doing randomized or grid search of best estimation in model parameter
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# for scalling the data
from sklearn.preprocessing import MinMaxScaler

# for calculating all scores
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,confusion_matrix,roc_auc_score, r2_score

# all different models used here
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier

# to plot confusion matrix of predicted and Y_test value
from sklearn.metrics import confusion_matrix

# to ignore warning
import warnings
warnings.filterwarnings('ignore')

# input data files are available in the read-only "../input/" directory
# for example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import os
for dirname, _, filenames in os.walk(''):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:\Anaconda\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
df = pd.read_csv('Titanic.csv', delimiter=',')
df.head()
# Out:
#    PassengerID                                           Name PClass    Age  \
# 0            1                   Allen, Miss Elisabeth Walton    1st  29.00
# 1            2                    Allison, Miss Helen Loraine    1st   2.00
# 2            3            Allison, Mr Hudson Joshua Creighton    1st  30.00
# 3            4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00
# 4            5                  Allison, Master Hudson Trevor    1st   0.92
#
#       Sex  Survived  SexCode
# 0  female         1        1
# 1  female         0        1
# 2    male         0        0
# 3  female         0        1
# 4    male         1        0

# %%
print(df.isnull().sum())
sns.heatmap(df.isnull(), cbar = False).set_title("Missing values heatmap") 
print(df.nunique())

df
# Out:
# PassengerID      0
# Name             0
# PClass           0
# Age            557
# Sex              0
# Survived         0
# SexCode          0
# dtype: int64
# PassengerID    1313
# Name           1310
# PClass            4
# Age              75
# Sex               2
# Survived          2
# SexCode           2
# dtype: int64
#       PassengerID                                              Name PClass  \
# 0               1                      Allen, Miss Elisabeth Walton    1st
# 1               2                       Allison, Miss Helen Loraine    1st
# 2               3               Allison, Mr Hudson Joshua Creighton    1st
# 3               4     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4               5                     Allison, Master Hudson Trevor    1st
# 5               6                                Anderson, Mr Harry    1st
# 6               7                  Andrews, Miss Kornelia Theodosia    1st
# ...

# %%
df_inputs = df.copy()

titanic = df_inputs.dropna()

df_inputs.Age[df_inputs.Age.isnull()] = titanic.Age.median()

titanic.Age[titanic.Age.isnull()] = titanic.Age.median()

# %%
df
# Out:
#       PassengerID                                              Name PClass  \
# 0               1                      Allen, Miss Elisabeth Walton    1st
# 1               2                       Allison, Miss Helen Loraine    1st
# 2               3               Allison, Mr Hudson Joshua Creighton    1st
# 3               4     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4               5                     Allison, Master Hudson Trevor    1st
# 5               6                                Anderson, Mr Harry    1st
# 6               7                  Andrews, Miss Kornelia Theodosia    1st
# 7               8                            Andrews, Mr Thomas, jr    1st
# 8               9      Appleton, Mrs Edward Dale (Charlotte Lamson)    1st
# 9              10                            Artagaveytia, Mr Ramon    1st
# 10             11                         Astor, Colonel John Jacob    1st
# ...

# %%
sns.heatmap(df.isnull(), cbar = False).set_title("Missing values heatmap")
# Out:
# Text(0.5,1,'Missing values heatmap')

# %%
sns.heatmap(df_inputs.isnull(), cbar = False).set_title("Missing values heatmap")
# Out:
# Text(0.5,1,'Missing values heatmap')

# %%
df_inputs
# Out:
#       PassengerID                                              Name PClass  \
# 0               1                      Allen, Miss Elisabeth Walton    1st
# 1               2                       Allison, Miss Helen Loraine    1st
# 2               3               Allison, Mr Hudson Joshua Creighton    1st
# 3               4     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4               5                     Allison, Master Hudson Trevor    1st
# 5               6                                Anderson, Mr Harry    1st
# 6               7                  Andrews, Miss Kornelia Theodosia    1st
# 7               8                            Andrews, Mr Thomas, jr    1st
# 8               9      Appleton, Mrs Edward Dale (Charlotte Lamson)    1st
# 9              10                            Artagaveytia, Mr Ramon    1st
# 10             11                         Astor, Colonel John Jacob    1st
# ...

# %%
sns_plotAge = sns.histplot(df_inputs[['Age']], x='Age')

# %%
sns_plotAge = sns.histplot(df_inputs, x='Age', hue='Sex')

# %%
sns_plotAge = sns.histplot(df_inputs, x='Sex', hue='Age')

# %%
sns_plotAge = sns.histplot(df_inputs, x='PClass', hue='Survived')

# %%
df_inputs.PClass.value_counts()
#df_inputs.PClass[df_inputs.PClass == '*'] = "3rd"
# Out:
# 3rd    712
# 1st    322
# 2nd    279
# Name: PClass, dtype: int64

# %%
sns_plotAge = sns.histplot(df_inputs, x='Sex', hue='Survived')

# %%
sns_plotAge = sns.histplot(df_inputs, x='Age', hue='Survived')

# %%
g = sns.catplot(x="Survived", col="PClass", col_wrap=3,
                data=df_inputs[['PClass', 'Survived', 'Sex']],
                kind="count", height=5, aspect=.8, hue = "Sex")

# %%
g = sns.catplot(x="Survived", y="Age", hue="Sex",
                col="PClass", data=df_inputs,
                height=5, aspect=.8)

# %%
g = sns.catplot(x="Survived", y="Age", hue="Sex",
               data=df_inputs, kind="violin")

# %%
import statistics

print("Variance of Age set is %s" %(statistics.variance(data=df_inputs["Age"])))
print("Variance of Sex set is %s" %(statistics.variance(data=df_inputs["SexCode"])))
print("Variance of Age set is %s" %(statistics.variance(data=df_inputs["Survived"])))
# Out:
# Variance of Age set is 118.40788851146138
# Variance of Sex set is 0.2282301283599279
# Variance of Age set is 0.2254367674103245

# %%
sns.heatmap(data=df_inputs[['Age']])

# %%
df_inputs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 7 columns):
# PassengerID    1313 non-null int64
# Name           1313 non-null object
# PClass         1313 non-null object
# Age            1313 non-null float64
# Sex            1313 non-null object
# Survived       1313 non-null int64
# SexCode        1313 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 71.9+ KB

# %%
np.mean(df_inputs.Age)
# Out:
# 29.380715917745626

# %%
np.var(df_inputs[['Age', 'Survived', 'SexCode']])
# Out:
# Age         118.317707
# Survived      0.225265
# SexCode       0.228056
# dtype: float64

# %%
df_inputs.shape
# Out:
# (1313, 7)

# %%
df_inputs[['Age', 'Survived', 'SexCode']].describe()
# Out:
#                Age     Survived      SexCode
# count  1313.000000  1313.000000  1313.000000
# mean     29.380716     0.342727     0.351866
# std      10.881539     0.474802     0.477734
# min       0.170000     0.000000     0.000000
# 25%      26.000000     0.000000     0.000000
# 50%      28.000000     0.000000     0.000000
# 75%      30.000000     1.000000     1.000000
# max      71.000000     1.000000     1.000000

# %%
df_inputs_encoding = pd.get_dummies(df_inputs[['Sex', 'Age', 'Survived']])

# %%
df_inputs[['Age', 'SexCode', 'Survived']].corr()
# Out:
#                Age   SexCode  Survived
# Age       1.000000 -0.034561 -0.028881
# SexCode  -0.034561  1.000000  0.502891
# Survived -0.028881  0.502891  1.000000

# %%
df_i_encoding = pd.get_dummies(df_inputs[['PClass', 'SexCode', 'Survived', 'Age']])
df_i_encoding
# Out:
#       SexCode  Survived    Age  PClass_1st  PClass_2nd  PClass_3rd
# 0           1         1  29.00           1           0           0
# 1           1         0   2.00           1           0           0
# 2           0         0  30.00           1           0           0
# 3           1         0  25.00           1           0           0
# 4           0         1   0.92           1           0           0
# 5           0         1  47.00           1           0           0
# 6           1         1  63.00           1           0           0
# 7           0         0  39.00           1           0           0
# 8           1         1  58.00           1           0           0
# 9           0         0  71.00           1           0           0
# 10          0         0  47.00           1           0           0
# 11          1         1  19.00           1           0           0
# 12          1         1  28.00           1           0           0
# ...

# %%
pd.crosstab(df_i_encoding.Survived, df_i_encoding.SexCode).plot(kind='bar', figsize=(20,10), color=["cyan", "magenta"])
plt.title("")
plt.xlabel("0 = Alive, 1 = Dead")
plt.ylabel("Count")
plt.legend(["Female","Male"])
plt.xticks(rotation=0);

# %%
cor_mat=df_inputs[['Age', 'SexCode', 'Survived']].corr()
fig,ax=plt.subplots(figsize=(15,10))
sns.heatmap(cor_mat,annot=True,linewidths=0.5,fmt=".3f")

# %%
fig,ax=plt.subplots()
ax=sns.heatmap(confusion_matrix(y_test,LR_model_y_pred),annot=True,cbar=True)
